# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/Kaggle/blob/main/Unzip_Gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Unzip Kaggle dataset in Gdrive**

# %%
#Gdriveをマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Zipファイルを指定のフォルダに展開

# !unzip "/content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection.zip" -d "/content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection"
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/691.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/692.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/693.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/694.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/695.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/696.dcm
#   inflating: /content/drive/MyDrive/Kaggle/rsna-2022-cervical-spine-fracture-detection/train_images/1.2.826.0.1.3680043.22930/697.dcm
# ...
